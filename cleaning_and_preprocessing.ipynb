# %% [markdown]
# # Churn Rate Cleaning and Preprocessing

# %%
# imports
import pandas as pd
import re

# %% [markdown]
# ## Load Data

# %%
# Load data
df = pd.read_csv('data/metadata_dataset.csv')
# show column names
df.columns.tolist()
# Out:
# ["[1]{'Version'}[1]{'ContractItem'}[1]{'CancellationStatusCode'}[1]{'Content'}",
#  "[1]{'Version'}[1]{'ContractItem'}[1]{'CustomerContractLifeCycleStatusCode'}[1]{'Content'}",
#  "[1]{'Version'}[1]{'ContractItem'}[1]{'Description'}[1]{'Content'}",
#  "[1]{'Version'}[1]{'ContractItem'}[1]{'InternalID'}[1]{'Content'}",
#  "[1]{'Version'}[1]{'ContractItem'}[1]{'ProductCategory'}[1]{'Content'}",
#  "[1]{'Version'}[1]{'ContractItem'}[1]{'ProductDescription'}[1]{'Content'}",
#  "[1]{'Version'}[1]{'ContractItem'}[1]{'SupportEndDate'}[1]{'Content'}",
#  "[1]{'Version'}[1]{'ContractItem'}[1]{'SupportStartDate'}[1]{'Content'}",
#  "[1]{'Version'}[1]{'ContractItem'}[1]{'ValidityStatusCode'}[1]{'Content'}",
#  "[1]{'Version'}[1]{'ContractItem'}[1]{'ConcurrentSessions'}[1]{'Content'}",
#  "[1]{'Version'}[1]{'Description'}[1]{'Content'}",
#  "[1]{'Version'}[1]{'EndDateTime'}[1]{'Content'}",
#  "[1]{'Version'}[1]{'StartDateTime'}[1]{'Content'}",
#  "[1]{'Version'}[1]{'ItemCount'}[1]{'Content'}",
#  "[1]{'Version'}[1]{'ItemListCancellationStatusCode'}[1]{'Content'}",
#  "[1]{'Version'}[1]{'ItemListCustomerContractLifeCycleStatusCode'}[1]{'Content'}",
#  "[1]{'Version'}[1]{'ItemListValidityStatusCode'}[1]{'Content'}",
#  "[1]{'Version'}[1]{'SAPInternalID'}[1]{'Content'}",
#  'contract_label',
#  'customer_earliest_start',
#  'customer_latest_end',
#  'customer_label',
#  'SLA',
#  'ProductCategory',
#  'service_level_regex',
#  'otrs_version',
#  'system_type',
#  'feature_add_ons',
#  'cancellation_date',
#  'customer_country',
#  'concat_volume',
#  'concat_currency',
#  'cancellation_date_orca',
#  'xml_key',
#  "[1]{'Version'}[1]{'EndCustomerID'}[1]{'Content'}",
#  "[1]{'Version'}[1]{'OTRSSystemID'}[1]{'Content'}"]

# %% [markdown]
# ## Rename columns for readability and consistency

# %%
# remove useless column name parts
df.columns = df.columns.str.replace(r"\[1\]", "", regex=True)
df.columns = df.columns.str.replace(r"\{'Content'\}", "", regex=True)
df.columns = df.columns.str.replace(r"\{'Version'\}", "", regex=True)
df.columns = df.columns.str.replace(r'[{}\']', '', regex=True)

# convert camel to snake case
def camel_to_snake(name):
    s1 = re.sub('(.)([A-Z][a-z]+)', r'\1_\2', name)  # Insert underscores between lower and upper case letters
    return re.sub('([a-z0-9])([A-Z])', r'\1_\2', s1).lower()  # Handle transition from lowercase/number to uppercase

df.columns = [camel_to_snake(col) for col in df.columns]

# Print the updated column names
print(df.columns.tolist())
# Out:
# ['contract_item_cancellation_status_code', 'contract_item_customer_contract_life_cycle_status_code', 'contract_item_description', 'contract_item_internal_id', 'contract_item_product_category', 'contract_item_product_description', 'contract_item_support_end_date', 'contract_item_support_start_date', 'contract_item_validity_status_code', 'contract_item_concurrent_sessions', 'description', 'end_date_time', 'start_date_time', 'item_count', 'item_list_cancellation_status_code', 'item_list_customer_contract_life_cycle_status_code', 'item_list_validity_status_code', 'sap_internal_id', 'contract_label', 'customer_earliest_start', 'customer_latest_end', 'customer_label', 'sla', 'product_category', 'service_level_regex', 'otrs_version', 'system_type', 'feature_add_ons', 'cancellation_date', 'customer_country', 'concat_volume', 'concat_currency', 'cancellation_date_orca', 'xml_key', 'end_customer_id', 'otrs_system_id']

# %% [markdown]
# ## Convert all time columns to datetime

# %%
import warnings
warnings.filterwarnings("ignore", category=UserWarning, message=".*Could not infer format.*")

# Convert columns with 'start', 'end', 'date' in the column name to datetime
date_columns = df.columns[df.columns.str.contains('start|_end|end_date|date', case=False)]
for col in date_columns:
    df[col] = pd.to_datetime(df[col], errors='coerce')

# %% [markdown]
# ## Convert all numerical columns to numeric if they are not already

# %%
# concat_volume column contains commas and dots, remove commas and replace dots with commas
df['concat_volume'] = df['concat_volume'].str.replace('.', '', regex=False)  
df['concat_volume'] = df['concat_volume'].str.replace(',', '.', regex=False) 
df['concat_volume'] = pd.to_numeric(df['concat_volume'])

# %% [markdown]
# ## Get a general overview of the data types and missing values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 208 entries, 0 to 207
# Data columns (total 36 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   contract_item_cancellation_status_code                  208 non-null    object
#  1   contract_item_customer_contract_life_cycle_status_code  208 non-null    object
#  2   contract_item_description                               208 non-null    object
#  3   contract_item_internal_id                               208 non-null    int64
#  4   contract_item_product_category                          208 non-null    object
#  5   contract_item_product_description                       208 non-null    object
#  6   contract_item_support_end_date                          208 non-null    datetime64[ns]
#  7   contract_item_support_start_date                        208 non-null    datetime64[ns]
#  8   contract_item_validity_status_code                      208 non-null    object
#  9   contract_item_concurrent_sessions                       197 non-null    float64
#  10  description                                             208 non-null    object
#  11  end_date_time                                           208 non-null    datetime64[ns]
#  12  start_date_time                                         208 non-null    datetime64[ns]
#  13  item_count                                              208 non-null    int64
#  14  item_list_cancellation_status_code                      208 non-null    object
#  15  item_list_customer_contract_life_cycle_status_code      208 non-null    object
#  16  item_list_validity_status_code                          208 non-null    object
#  17  sap_internal_id                                         208 non-null    object
#  18  contract_label                                          208 non-null    object
#  19  customer_earliest_start                                 208 non-null    datetime64[ns]
#  20  customer_latest_end                                     208 non-null    datetime64[ns]
#  21  customer_label                                          208 non-null    object
#  22  sla                                                     207 non-null    object
#  23  product_category                                        207 non-null    object
#  24  service_level_regex                                     208 non-null    object
#  25  otrs_version                                            208 non-null    object
#  26  system_type                                             208 non-null    object
#  27  feature_add_ons                                         208 non-null    object
#  28  cancellation_date                                       79 non-null     datetime64[ns]
#  29  customer_country                                        208 non-null    object
#  30  concat_volume                                           207 non-null    float64
#  31  concat_currency                                         207 non-null    object
#  32  cancellation_date_orca                                  79 non-null     datetime64[ns]
#  33  xml_key                                                 208 non-null    int64
#  34  end_customer_id                                         208 non-null    object
#  35  otrs_system_id                                          208 non-null    int64
# dtypes: datetime64[ns](8), float64(2), int64(4), object(22)
# memory usage: 58.6+ KB

# %% [markdown]
# ## Clean the ID columns

# %% [markdown]
# ### Check for duplicates in ID rows

# %%
# check number of distinct duplicates in columns with id in the name
for col in df.columns:
    if '_id' in col:
        print(f'{col}: {df[col].duplicated().sum()} duplicates')

print(f'xml_key: {df['xml_key'].duplicated().sum()} duplicates')
# Out:
# contract_item_internal_id: 204 duplicates
# sap_internal_id: 0 duplicates
# end_customer_id: 33 duplicates
# otrs_system_id: 0 duplicates
# xml_key: 0 duplicates

# %% [markdown]
# ### Drop ID columns with no duplicates

# %%
print(len(df.columns))
# drop columns with id in the name with no duplicates
df = df.drop(columns=[col for col in df.columns if '_id' in col and not df[col].duplicated().any()])
# drop column xml_key
df = df.drop(columns=['xml_key'])
print(len(df.columns))
# Out:
# 36
# 33

# %% [markdown]
# ## Save to CSV

# %%
df
# Out:
#     contract_item_cancellation_status_code  \
# 0                             Not Canceled
# 1                             Not Canceled
# 2                             Not Canceled
# 3                             Not Canceled
# 4                             Not Canceled
# ..                                     ...
# 203                 Cancellation Requested
# 204                           Not Canceled
# 205                 Cancellation Requested
# 206                           Not Canceled
# 207                           Not Canceled
#
#     contract_item_customer_contract_life_cycle_status_code  \
# 0                                           In Process
# 1                                           In Process
# 2                                           In Process
# 3                                           In Process
# 4                                           In Process
# ..                                                 ...
# 203                                         In Process
# 204                                          Completed
# 205                                         In Process
# 206                                         In Process
# 207                                         In Process
#
#                     contract_item_description  contract_item_internal_id  \
# 0                                   OTRS GOLD                         10
# 1                    OTRS On-Premise PLATINUM                         10
# 2                        OTRS On-Premise GOLD                         10
# 3           OTRS On-Premise GOLD (Testsystem)                         10
# 4                      OTRS On-Premise SILVER                         10
# ..                                        ...                        ...
# 203  OTRS Contract - Annual Support ENTRY ADV                         20
# 204                      OTRS On-Premise GOLD                         10
# 205                  OTRS On-Premise PLATINUM                         20
# 206                                 OTRS GOLD                         40
# 207                                 OTRS GOLD                         30
#
#     contract_item_product_category contract_item_product_description  \
# 0           Contracts Managed OTRS                         OTRS GOLD
# 1        Contracts On-Premise OTRS          OTRS On-Premise PLATINUM
# 2        Contracts On-Premise OTRS              OTRS On-Premise GOLD
# 3        Contracts On-Premise OTRS              OTRS On-Premise GOLD
# 4        Contracts On-Premise OTRS            OTRS On-Premise SILVER
# ..                             ...                               ...
# 203       Contracts On-Premise Old                         Old Basic
# 204      Contracts On-Premise OTRS              OTRS On-Premise GOLD
# 205      Contracts On-Premise OTRS          OTRS On-Premise PLATINUM
# 206         Contracts Managed OTRS                         OTRS GOLD
# 207         Contracts Managed OTRS                         OTRS GOLD
#
#     contract_item_support_end_date contract_item_support_start_date  \
# 0              2023-12-06 23:00:00              2022-12-06 23:00:00
# 1              2023-12-11 23:00:00              2022-12-11 23:00:00
# 2              2023-12-31 23:00:00              2022-12-31 23:00:00
# 3              2023-12-31 23:00:00              2022-12-31 23:00:00
# 4              2023-12-31 23:00:00              2022-12-31 23:00:00
# ..                             ...                              ...
# 203            2024-08-15 22:00:00              2023-08-15 22:00:00
# 204            2023-01-11 23:00:00              2022-10-11 22:00:00
# 205            2024-10-16 22:00:00              2023-10-16 22:00:00
# 206            2024-10-26 22:00:00              2023-10-26 22:00:00
# 207            2024-10-27 23:00:00              2023-10-27 22:00:00
#
#     contract_item_validity_status_code  contract_item_concurrent_sessions  \
# 0                               Active                               50.0
# 1                               Active                              300.0
# 2                               Active                               50.0
# 3                               Active                               50.0
# 4                               Active                               10.0
# ..                                 ...                                ...
# 203                             Active                                NaN
# 204                            Expired                               50.0
# 205                             Active                              200.0
# 206                             Active                               50.0
# 207                             Active                               10.0
#
#      ... service_level_regex otrs_version system_type  \
# 0    ...                Gold       7.0.48     managed
# 1    ...            Platinum       7.0.23        auto
# 2    ...                Gold       7.0.22        auto
# 3    ...                Gold       7.0.12        auto
# 4    ...              Silver       7.0.12        auto
# ..   ...                 ...          ...         ...
# 203  ...              Silver        5.0.1      manual
# 204  ...                Gold       8.0.36        auto
# 205  ...            Platinum       7.0.40        auto
# 206  ...                Gold     2023.1.1     managed
# 207  ...                Gold     2023.1.1     managed
#
#                                        feature_add_ons   cancellation_date  \
# 0    ['SaaSPortalConnector', 'OTRSCalendarResourceP...                 NaT
# 1    ['GeneralCatalog', 'OTRSSystemConfigurationHis...                 NaT
# 2    ['OTRSHideShowDynamicFields', 'OTRSEscalationS... 2017-05-16 08:38:00
# 3    ['GeneralCatalog', 'OTRSSystemConfigurationHis... 2017-05-16 08:38:00
# 4    ['OTRSAdvancedEscalations', 'AkquinetAssetSear... 2017-05-16 08:38:00
# ..                                                 ...                 ...
# 203                         ['FAQ', 'OTRSMasterSlave']                 NaT
# 204  ['OTRSCloneDB', 'Survey', 'OTRSConfigurationMa...                 NaT
# 205  ['OTRSMasterSlave', 'OTRSDynamicFieldDatabase'...                 NaT
# 206  ['OTRSStatePreselectionResponseTemplates', 'OT...                 NaT
# 207  ['OTRSStatePreselectionResponseTemplates', 'Sa...                 NaT
#
#              customer_country concat_volume concat_currency  \
# 0                     GERMANY       17495.0            Euro
# 1                       SPAIN       37800.0            Euro
# 2                     GERMANY        5995.0            Euro
# 3                     GERMANY        5995.0            Euro
# 4                     GERMANY        3995.0            Euro
# ..                        ...           ...             ...
# 203                   GERMANY        4995.0            Euro
# 204  UNITED STATES OF AMERICA       15047.0       US-Dollar
# 205                   AUSTRIA       25995.0            Euro
# 206                   GERMANY       15995.0            Euro
# 207  UNITED STATES OF AMERICA        5200.0       US-Dollar
#
#     cancellation_date_orca end_customer_id
# 0                      NaT        CFHbGks3
# 1                      NaT        laVvIOXe
# 2                      NaT        Yc6VmmVi
# 3                      NaT        Yc6VmmVi
# 4                      NaT        Yc6VmmVi
# ..                     ...             ...
# 203    2023-06-29 06:36:00        5gw4WtWX
# 204                    NaT        U00PI7xM
# 205                    NaT        Fs3qolwK
# 206                    NaT        JuFKu1yu
# 207                    NaT        B1pWck63
#
# [208 rows x 33 columns]

# %%
# save the clean dataframe to csv
df.to_csv("data/data_after_processing.csv")
